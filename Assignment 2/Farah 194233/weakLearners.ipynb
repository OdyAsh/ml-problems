# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import pandas as pd
from sklearn import metrics
from numpy.random import seed
from sklearn.model_selection import learning_curve
#from sklearn.metrics import plot_confusion_matrix
from mlxtend.evaluate import bias_variance_decomp
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
#seed(42)

# %% [markdown]
# ## Looking at the Pre-prossesed Data

# %%
df = pd.read_csv("../PhishingWebsites-ReducedAndStandardized.csv")
df
# Out:
#        Unnamed: 0        f0        f1        f2        f3        f4        f5  \
# 0               0 -0.432366 -1.926665  0.958237  0.402154 -1.486897 -0.589921
# 1               1  0.518745 -0.341130  0.958237  0.402154 -1.486897 -0.589921
# 2               2 -0.432366 -1.133898  0.178515  0.402154 -1.486897 -0.589921
# 3               3  0.518745 -0.341130  0.178515  0.402154 -1.486897 -0.589921
# 4               4 -0.432366 -0.341130  0.178515  0.402154 -1.486897 -0.589921
# ...           ...       ...       ...       ...       ...       ...       ...
# 11050       11050 -2.810144  0.451637 -0.601208  0.402154  0.672542 -0.589921
# 11051       11051 -1.859033 -1.133898  1.737960  0.402154  0.672542  1.695143
# 11052       11052  0.518745  0.451637 -0.601208  0.402154  0.672542 -0.589921
# 11053       11053 -0.907922  0.451637 -0.601208  0.402154  0.672542 -0.589921
# 11054       11054  0.043189  0.451637 -0.601208 -2.486611  0.672542 -0.589921
#
#              f6        f7        f8  ...       f10       f11       f12  \
# 0      1.151029  0.827776 -0.361705  ... -1.063235 -0.704374 -1.555270
# 1      1.151029  0.827776 -0.361705  ... -1.063235 -0.704374 -0.347097
# 2     -0.603608  0.827776 -0.361705  ...  0.940526 -0.704374  0.861076
# 3     -2.358245 -1.208056 -0.361705  ... -1.063235  1.419700  0.861076
# 4      1.151029  0.827776 -0.361705  ... -1.063235 -0.704374 -0.347097
# ...         ...       ...       ...  ...       ...       ...       ...
# 11050  1.151029  0.827776 -0.361705  ...  0.940526 -0.704374 -1.555270
# 11051 -2.358245  0.827776  2.764683  ...  0.940526 -0.704374  0.861076
# 11052 -0.603608  0.827776 -0.361705  ...  0.940526 -0.704374  0.861076
# 11053  1.151029 -1.208056 -0.361705  ...  0.940526  1.419700  0.861076
# 11054  1.151029 -1.208056 -0.361705  ... -1.063235  1.419700 -1.555270
#
#             f13       f14       f15       f16       f17       f18    t
# 0     -1.383683 -1.371855 -0.390849  0.419600 -1.301501 -1.291381 -1.0
# 1      0.722709  0.821486 -0.390849  0.419600 -0.078232  0.107014 -1.0
# 2      0.722709 -1.371855 -0.390849  0.419600 -1.301501  0.107014 -1.0
# 3      0.722709 -1.371855 -0.390849  0.419600 -1.301501  0.107014 -1.0
# 4      0.722709  0.821486 -0.390849  0.419600  1.145038  0.107014  1.0
# ...         ...       ...       ...       ...       ...       ...  ...
# 11050  0.722709  0.821486  2.558530 -2.383224  1.145038  1.505410  1.0
# 11051 -1.383683 -1.371855 -0.390849 -2.383224  1.145038 -1.291381 -1.0
# 11052  0.722709 -1.371855 -0.390849  0.419600  1.145038  0.107014 -1.0
# 11053 -1.383683 -1.371855 -0.390849  0.419600 -1.301501 -1.291381 -1.0
# 11054 -1.383683 -1.371855 -0.390849  0.419600 -1.301501 -1.291381 -1.0
#
# [11055 rows x 21 columns]

# %% [markdown]
# ### Removing the first column

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df
# Out:
#              f0        f1        f2        f3        f4        f5        f6  \
# 0     -0.432366 -1.926665  0.958237  0.402154 -1.486897 -0.589921  1.151029
# 1      0.518745 -0.341130  0.958237  0.402154 -1.486897 -0.589921  1.151029
# 2     -0.432366 -1.133898  0.178515  0.402154 -1.486897 -0.589921 -0.603608
# 3      0.518745 -0.341130  0.178515  0.402154 -1.486897 -0.589921 -2.358245
# 4     -0.432366 -0.341130  0.178515  0.402154 -1.486897 -0.589921  1.151029
# ...         ...       ...       ...       ...       ...       ...       ...
# 11050 -2.810144  0.451637 -0.601208  0.402154  0.672542 -0.589921  1.151029
# 11051 -1.859033 -1.133898  1.737960  0.402154  0.672542  1.695143 -2.358245
# 11052  0.518745  0.451637 -0.601208  0.402154  0.672542 -0.589921 -0.603608
# 11053 -0.907922  0.451637 -0.601208  0.402154  0.672542 -0.589921  1.151029
# 11054  0.043189  0.451637 -0.601208 -2.486611  0.672542 -0.589921  1.151029
#
#              f7        f8        f9       f10       f11       f12       f13  \
# 0      0.827776 -0.361705  1.463648 -1.063235 -0.704374 -1.555270 -1.383683
# 1      0.827776 -0.361705 -1.154365 -1.063235 -0.704374 -0.347097  0.722709
# 2      0.827776 -0.361705 -1.154365  0.940526 -0.704374  0.861076  0.722709
# 3     -1.208056 -0.361705  0.154642 -1.063235  1.419700  0.861076  0.722709
# 4      0.827776 -0.361705  0.154642 -1.063235 -0.704374 -0.347097  0.722709
# ...         ...       ...       ...       ...       ...       ...       ...
# 11050  0.827776 -0.361705  1.463648  0.940526 -0.704374 -1.555270  0.722709
# 11051  0.827776  2.764683 -1.154365  0.940526 -0.704374  0.861076 -1.383683
# 11052  0.827776 -0.361705 -1.154365  0.940526 -0.704374  0.861076  0.722709
# 11053 -1.208056 -0.361705  1.463648  0.940526  1.419700  0.861076 -1.383683
# 11054 -1.208056 -0.361705  0.154642 -1.063235  1.419700 -1.555270 -1.383683
#
#             f14       f15       f16       f17       f18    t
# 0     -1.371855 -0.390849  0.419600 -1.301501 -1.291381 -1.0
# 1      0.821486 -0.390849  0.419600 -0.078232  0.107014 -1.0
# 2     -1.371855 -0.390849  0.419600 -1.301501  0.107014 -1.0
# 3     -1.371855 -0.390849  0.419600 -1.301501  0.107014 -1.0
# 4      0.821486 -0.390849  0.419600  1.145038  0.107014  1.0
# ...         ...       ...       ...       ...       ...  ...
# 11050  0.821486  2.558530 -2.383224  1.145038  1.505410  1.0
# 11051 -1.371855 -0.390849 -2.383224  1.145038 -1.291381 -1.0
# 11052 -1.371855 -0.390849  0.419600  1.145038  0.107014 -1.0
# 11053 -1.371855 -0.390849  0.419600 -1.301501 -1.291381 -1.0
# 11054 -1.371855 -0.390849  0.419600 -1.301501 -1.291381 -1.0
#
# [11055 rows x 20 columns]

# %% [markdown]
# ## Splitting Data

# %%
x = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
x
# Out:
#              f0        f1        f2        f3        f4        f5        f6  \
# 0     -0.432366 -1.926665  0.958237  0.402154 -1.486897 -0.589921  1.151029
# 1      0.518745 -0.341130  0.958237  0.402154 -1.486897 -0.589921  1.151029
# 2     -0.432366 -1.133898  0.178515  0.402154 -1.486897 -0.589921 -0.603608
# 3      0.518745 -0.341130  0.178515  0.402154 -1.486897 -0.589921 -2.358245
# 4     -0.432366 -0.341130  0.178515  0.402154 -1.486897 -0.589921  1.151029
# ...         ...       ...       ...       ...       ...       ...       ...
# 11050 -2.810144  0.451637 -0.601208  0.402154  0.672542 -0.589921  1.151029
# 11051 -1.859033 -1.133898  1.737960  0.402154  0.672542  1.695143 -2.358245
# 11052  0.518745  0.451637 -0.601208  0.402154  0.672542 -0.589921 -0.603608
# 11053 -0.907922  0.451637 -0.601208  0.402154  0.672542 -0.589921  1.151029
# 11054  0.043189  0.451637 -0.601208 -2.486611  0.672542 -0.589921  1.151029
#
#              f7        f8        f9       f10       f11       f12       f13  \
# 0      0.827776 -0.361705  1.463648 -1.063235 -0.704374 -1.555270 -1.383683
# 1      0.827776 -0.361705 -1.154365 -1.063235 -0.704374 -0.347097  0.722709
# 2      0.827776 -0.361705 -1.154365  0.940526 -0.704374  0.861076  0.722709
# 3     -1.208056 -0.361705  0.154642 -1.063235  1.419700  0.861076  0.722709
# 4      0.827776 -0.361705  0.154642 -1.063235 -0.704374 -0.347097  0.722709
# ...         ...       ...       ...       ...       ...       ...       ...
# 11050  0.827776 -0.361705  1.463648  0.940526 -0.704374 -1.555270  0.722709
# 11051  0.827776  2.764683 -1.154365  0.940526 -0.704374  0.861076 -1.383683
# 11052  0.827776 -0.361705 -1.154365  0.940526 -0.704374  0.861076  0.722709
# 11053 -1.208056 -0.361705  1.463648  0.940526  1.419700  0.861076 -1.383683
# 11054 -1.208056 -0.361705  0.154642 -1.063235  1.419700 -1.555270 -1.383683
#
#             f14       f15       f16       f17       f18
# 0     -1.371855 -0.390849  0.419600 -1.301501 -1.291381
# 1      0.821486 -0.390849  0.419600 -0.078232  0.107014
# 2     -1.371855 -0.390849  0.419600 -1.301501  0.107014
# 3     -1.371855 -0.390849  0.419600 -1.301501  0.107014
# 4      0.821486 -0.390849  0.419600  1.145038  0.107014
# ...         ...       ...       ...       ...       ...
# 11050  0.821486  2.558530 -2.383224  1.145038  1.505410
# 11051 -1.371855 -0.390849 -2.383224  1.145038 -1.291381
# 11052 -1.371855 -0.390849  0.419600  1.145038  0.107014
# 11053 -1.371855 -0.390849  0.419600 -1.301501 -1.291381
# 11054 -1.371855 -0.390849  0.419600 -1.301501 -1.291381
#
# [11055 rows x 19 columns]

# %%
y
# Out:
# 0       -1.0
# 1       -1.0
# 2       -1.0
# 3       -1.0
# 4        1.0
#         ...
# 11050    1.0
# 11051   -1.0
# 11052   -1.0
# 11053   -1.0
# 11054   -1.0
# Name: t, Length: 11055, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42, stratify = y)

# %% [markdown]
# ## Looking at the Balance of the Data

# %%
y.value_counts()
# Out:
#  1.0    6157
# -1.0    4898
# Name: t, dtype: int64

# %%
labels = 'phising', 'not phising'
sizes = y.value_counts().values
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# As seen above, after the ppre-prossing of the data, the data is balanced and ready to be fed to the models.

# %% [markdown]
# ## (1) Support Vector Machines

# %% [markdown]
# The first model we wil test is SVM and test all its hyperparamters.

# %% [markdown]
# We will test different kernels to determine the best kernel that will perform better on the data

# %%
kernels = ['linear', 'poly', 'rbf']
scores_test = []
scores_train = []
for k in kernels:
    if k == "poly4":
        svc = SVC(kernel='poly', degree=2).fit(x_train, y_train)
    else:
        svc = SVC(kernel=k).fit(x_train, y_train)
        
    y_pred = svc.predict(x_test)
    scores_train.append(metrics.accuracy_score(y_train, svc.predict(x_train)))
    scores_test.append(metrics.accuracy_score(y_test, y_pred))

print(scores_test)
plt.plot(kernels, scores_train, label="train scores")
plt.plot(kernels, scores_test, label="test scores")
plt.xlabel(' Kernel')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# [0.9237262586674706, 0.9451311425987338, 0.9511606873681037]

# %% [markdown]
# Looking at the plot above, we will find that the RBF kernel performed best on the data

# %% [markdown]
# Nevertheless, we will also test the polynomial kernel on different degrees to see if it might score better than the RBF

# %%
nums = range(1,10)
scores_test = []
scores_train = []
for i in nums:
    svc = SVC(kernel='poly', degree=i).fit(x_train, y_train)
    y_pred = svc.predict(x_test)
    scores_train.append(metrics.accuracy_score(y_train, svc.predict(x_train)))
    scores_test.append(metrics.accuracy_score(y_test, y_pred))

print(scores_test)
plt.plot(nums, scores_train, label="train scores")
plt.plot(nums, scores_test, label="test scores")
plt.xlabel(' Degree no.')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# [0.9228218269520652, 0.9258365993367501, 0.9451311425987338, 0.9475429605064818, 0.9436237564063913, 0.9137775097980102, 0.9035272836900814, 0.8510702441965632, 0.8359963822731383]

# %% [markdown]
# Looking in the plot above, we will see that degree 4 performs best an it is close to the results of RBF kernel so we will be testing it seperately

# %% [markdown]
# Trying different C parameters on polynomial kernel degree 4:

# %%
cs = range(1,10)
nums = range(1,10)
scores_test = []
scores_train = []
for c in cs:
    svc = SVC(kernel='poly', C=c, degree = 4).fit(x_train, y_train)
    y_pred = svc.predict(x_test)
    scores_train.append(metrics.accuracy_score(y_train, svc.predict(x_train)))
    scores_test.append(metrics.accuracy_score(y_test, y_pred))

print(scores_test)
plt.plot(cs, scores_train, label="train scores")
plt.plot(cs, scores_test, label="test scores")
plt.xlabel(' C')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# [0.9475429605064818, 0.9550798914681942, 0.9593005728067531, 0.9565872776605366, 0.9556828459451311, 0.9538739825143202, 0.9529695507989147, 0.9526680735604461, 0.9529695507989147]

# %% [markdown]
# The parameter chosen will be C=1 since the gap between the training and testing is the least when C=1 while in the other values, the gap increases exponentially.

# %% [markdown]
# Looking at the accuracies of the polynomial kernel with dgree 4 and c=1:

# %%
clf = SVC(kernel='poly', degree=4, C=1, random_state=42)
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)
# generate evaluation metrics
print("Train ACC:", metrics.accuracy_score(y_train, clf.predict(x_train)))
print("Train CM:",metrics.confusion_matrix(y_train, clf.predict(x_train)))
print("Train CR:", metrics.classification_report(y_train, clf.predict(x_train)))

print("Test ACC:", metrics.accuracy_score(y_test, clf.predict(x_test)))
print("Test CM:",metrics.confusion_matrix(y_test, clf.predict(x_test)))
print("Test CR:", metrics.classification_report(y_test, clf.predict(x_test)))
# Out:
# Train ACC: 0.9583871801499095
# Train CM: [[3195  233]
#  [  89 4221]]
# Train CR:               precision    recall  f1-score   support
#
#         -1.0       0.97      0.93      0.95      3428
#          1.0       0.95      0.98      0.96      4310
#
#     accuracy                           0.96      7738
#    macro avg       0.96      0.96      0.96      7738
# weighted avg       0.96      0.96      0.96      7738
#
# Test ACC: 0.9475429605064818
# Test CM: [[1342  128]
#  [  46 1801]]
# Test CR:               precision    recall  f1-score   support
#
#         -1.0       0.97      0.91      0.94      1470
#          1.0       0.93      0.98      0.95      1847
#
#     accuracy                           0.95      3317
#    macro avg       0.95      0.94      0.95      3317
# weighted avg       0.95      0.95      0.95      3317

# %%
train_sizes_model, train_scores_model, valid_scores_model, *_ =learning_curve(clf, x, y,cv=5,
                    scoring='accuracy',n_jobs=-1)
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.scatter(x=train_sizes_model,y= train_scores_model.mean(axis=1))
ax.scatter(x=train_sizes_model,y=valid_scores_model.mean(axis=1))
ax.plot(train_sizes_model,train_scores_model.mean(axis=1))
ax.plot(train_sizes_model,valid_scores_model.mean(axis=1))
ax.set_xlabel('Data Range')
ax.set_ylabel('Accuracy')
ax.set_title('Learning Curve')
plt.show()

# %%
mse, bias, var = bias_variance_decomp\
(clf, x_train.values, y_train.values, x_test.values, y_test.values, loss='mse', num_rounds=20, random_seed=42)
print('MSE: %.3f' % mse)
print('Bias: %.3f' % bias)
print('Variance: %.3f' % var)
# Out:
# MSE: 0.243
# Bias: 0.178
# Variance: 0.065

# %% [markdown]
# Trying different Cs with RBF kernel:

# %%
cs = range(1,10)
nums = range(1,10)
scores_test = []
scores_train = []
for c in cs:
    svc = SVC(kernel='rbf', C=c).fit(x_train, y_train)
    y_pred = svc.predict(x_test)
    scores_train.append(metrics.accuracy_score(y_train, svc.predict(x_train)))
    scores_test.append(metrics.accuracy_score(y_test, y_pred))

print(scores_test)
plt.plot(cs, scores_train, label="train scores")
plt.plot(cs, scores_test, label="test scores")
plt.xlabel(' C')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# [0.9511606873681037, 0.9565872776605366, 0.9586976183298161, 0.9611094362375641, 0.9626168224299065, 0.9632197769068436, 0.9644256858607175, 0.964124208622249, 0.964124208622249]

# %% [markdown]
# The parameter chosen will be C=1 since the gap between the training and testing is the least when C=1 while in the other values, the gap increases exponentially.

# %%
svc = SVC(kernel='rbf', C=1, random_state=0)
svc.fit(x_train, y_train)
y_pred = svc.predict(x_test)
# generate evaluation metrics
print("Train ACC:", metrics.accuracy_score(y_train, svc.predict(x_train)))
print("Train CM:",metrics.confusion_matrix(y_train, svc.predict(x_train)))
print("Train CR:", metrics.classification_report(y_train, svc.predict(x_train)))

print("Test ACC:", metrics.accuracy_score(y_test, svc.predict(x_test)))
print("Test CM:",metrics.confusion_matrix(y_test, svc.predict(x_test)))
print("Test CR:", metrics.classification_report(y_test, svc.predict(x_test)))
# Out:
# Train ACC: 0.9572240889118635
# Train CM: [[3218  210]
#  [ 121 4189]]
# Train CR:               precision    recall  f1-score   support
#
#         -1.0       0.96      0.94      0.95      3428
#          1.0       0.95      0.97      0.96      4310
#
#     accuracy                           0.96      7738
#    macro avg       0.96      0.96      0.96      7738
# weighted avg       0.96      0.96      0.96      7738
#
# Test ACC: 0.9511606873681037
# Test CM: [[1363  107]
#  [  55 1792]]
# Test CR:               precision    recall  f1-score   support
#
#         -1.0       0.96      0.93      0.94      1470
#          1.0       0.94      0.97      0.96      1847
#
#     accuracy                           0.95      3317
#    macro avg       0.95      0.95      0.95      3317
# weighted avg       0.95      0.95      0.95      3317

# %%
train_sizes_model, train_scores_model, valid_scores_model, *_ =learning_curve(svc, x, y,cv=5,
                    scoring='accuracy',n_jobs=-1)
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.scatter(x=train_sizes_model,y= train_scores_model.mean(axis=1))
ax.scatter(x=train_sizes_model,y=valid_scores_model.mean(axis=1))
ax.plot(train_sizes_model,train_scores_model.mean(axis=1))
ax.plot(train_sizes_model,valid_scores_model.mean(axis=1))
ax.set_xlabel('Data Range')
ax.set_ylabel('Accuracy')
ax.set_title('Learning Curve')
plt.show()

# %%
auc = roc_auc_score(y_pred, y_test)

fpr, tpr, thresholds = roc_curve(y_test, y_pred)
plt.plot(fpr, tpr,label ='AUC:%.3f'%auc)

plt.legend(loc=4)
plt.show()

# %%
mse, bias, var = bias_variance_decomp\
(svc, x_train.values, y_train.values, x_test.values, y_test.values, loss='mse', num_rounds=20, random_seed=42)
print('MSE: %.3f' % mse)
print('Bias: %.3f' % bias)
print('Variance: %.3f' % var)
# Out:
# MSE: 0.207
# Bias: 0.170
# Variance: 0.036

# %% [markdown]
# ### Comparing RBF and polynomail kernel at degree 1

# %% [markdown]
# As seen in both models, the results either the accuracy, MSE, bias and variance are close. The polynnomial kernel had a slight higher accuracy but the MSE of the RBF and its variance were lower. Also, looking at the learning curve of the polynomial kernel, at the end of the curve, it indicates that might cause overfitting if the data was bigger.

# %% [markdown]
# ## (2) Decision Trees

# %%
depths = range(1,20)
scores_test = []
scores_train = []
for depth in depths:

    tree = DecisionTreeClassifier(random_state=42, max_depth=depth)
    tree.fit(x_train, y_train)
    y_pred_dt = tree.predict(x_test)
    scores_train.append(metrics.accuracy_score(y_train, tree.predict(x_train)))
    scores_test.append(metrics.accuracy_score(y_test, y_pred_dt))
    
print(scores_test)
plt.plot(depths, scores_train, label="train scores")
plt.plot(depths, scores_test, label="test scores")
plt.xlabel('max depth')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# [0.8866445583358457, 0.9071450105517034, 0.9083509195055773, 0.9231233041905336, 0.9270425082906241, 0.9321676213445885, 0.934880916490805, 0.9384986433524269, 0.9412119384986434, 0.9526680735604461, 0.9499547784142297, 0.9577931866144106, 0.9553813687066627, 0.9638227313837805, 0.9626168224299065, 0.9602050045221586, 0.9614109134760326, 0.9632197769068436, 0.9620138679529695]

# %%
tree = DecisionTreeClassifier(random_state=42, max_depth=10)
tree.fit(x_train, y_train)
y_pred_dt = tree.predict(x_test)
print("Train ACC:", metrics.accuracy_score(y_train, tree.predict(x_train)))
print("Train CM:",metrics.confusion_matrix(y_train, tree.predict(x_train)))
print("Train CR:", metrics.classification_report(y_train, tree.predict(x_train)))

print("Test ACC:", metrics.accuracy_score(y_test, tree.predict(x_test)))
print("Test CM:",metrics.confusion_matrix(y_test, tree.predict(x_test)))
print("Test CR:", metrics.classification_report(y_test, tree.predict(x_test)))
# Out:
# Train ACC: 0.9608425949857844
# Train CM: [[3309  119]
#  [ 184 4126]]
# Train CR:               precision    recall  f1-score   support
#
#         -1.0       0.95      0.97      0.96      3428
#          1.0       0.97      0.96      0.96      4310
#
#     accuracy                           0.96      7738
#    macro avg       0.96      0.96      0.96      7738
# weighted avg       0.96      0.96      0.96      7738
#
# Test ACC: 0.9526680735604461
# Test CM: [[1395   75]
#  [  82 1765]]
# Test CR:               precision    recall  f1-score   support
#
#         -1.0       0.94      0.95      0.95      1470
#          1.0       0.96      0.96      0.96      1847
#
#     accuracy                           0.95      3317
#    macro avg       0.95      0.95      0.95      3317
# weighted avg       0.95      0.95      0.95      3317

# %%
train_sizes_model, train_scores_model, valid_scores_model, *_ =learning_curve(tree, x, y,cv=5,
                    scoring='accuracy',n_jobs=-1)
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.scatter(x=train_sizes_model,y= train_scores_model.mean(axis=1))
ax.scatter(x=train_sizes_model,y=valid_scores_model.mean(axis=1))
ax.plot(train_sizes_model,train_scores_model.mean(axis=1))
ax.plot(train_sizes_model,valid_scores_model.mean(axis=1))
ax.set_xlabel('Data Range')
ax.set_ylabel('Accuracy')
ax.set_title('Learning Curve')
plt.show()

# %%
auc = roc_auc_score(y_pred_dt, y_test)

fpr, tpr, thresholds = roc_curve(y_test, y_pred_dt)
plt.plot(fpr, tpr,label ='AUC:%.3f'%auc)

plt.legend(loc=4)
plt.show()

# %%
mse, bias, var = bias_variance_decomp\
(tree, x_train.values, y_train.values, x_test.values, y_test.values, loss='mse', num_rounds=20, random_seed=42)
print('MSE: %.3f' % mse)
print('Bias: %.3f' % bias)
print('Variance: %.3f' % var)
# Out:
# MSE: 0.238
# Bias: 0.124
# Variance: 0.114

# %% [markdown]
# ## (3) Logistic Regression

# %% [markdown]
# As suggested by the logistic regression documnetation,  'liblinear' is a good choice for small datasets, whereas 'sag' and 'saga' are faster for large ones. For multiclass problems, only 'newton-cag', 'sag', 'saga' and 'lbfgs' handle multinomial loss.

# %%
scores_test = []
scores_train = []
cs=[0.001,0.01, 0.1, 1]
for c in cs:
    model = LogisticRegression(random_state=42, solver = 'liblinear', C=c)
    model = model.fit(x_train, y_train)
    y_pred_lr = model.predict(x_test)
    scores_train.append(metrics.accuracy_score(y_train, model.predict(x_train)))
    scores_test.append(metrics.accuracy_score(y_test, y_pred_lr))

print(scores_test)
print(scores_train)

plt.plot(cs, scores_train, label="train scores")
plt.plot(cs, scores_test, label="test scores")
plt.xlabel('C')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# [0.9164908049442267, 0.9234247814290021, 0.9258365993367501, 0.9261380765752185]
# [0.9229775135693977, 0.9263375549237529, 0.9282760403204963, 0.9276298785215819]

# %%
model = LogisticRegression(random_state=42, solver = 'liblinear', C=1)
model = model.fit(x_train, y_train)
y_pred_lr = model.predict(x_test)

print("Train ACC:", metrics.accuracy_score(y_train, model.predict(x_train)))
print("Train CM:",metrics.confusion_matrix(y_train, model.predict(x_train)))
print("Train CR:", metrics.classification_report(y_train, model.predict(x_train)))

print("Test ACC:", metrics.accuracy_score(y_test, model.predict(x_test)))
print("Test CM:",metrics.confusion_matrix(y_test, model.predict(x_test)))
print("Test CR:", metrics.classification_report(y_test, model.predict(x_test)))
# Out:
# Train ACC: 0.9276298785215819
# Train CM: [[3095  333]
#  [ 227 4083]]
# Train CR:               precision    recall  f1-score   support
#
#         -1.0       0.93      0.90      0.92      3428
#          1.0       0.92      0.95      0.94      4310
#
#     accuracy                           0.93      7738
#    macro avg       0.93      0.93      0.93      7738
# weighted avg       0.93      0.93      0.93      7738
#
# Test ACC: 0.9261380765752185
# Test CM: [[1331  139]
#  [ 106 1741]]
# Test CR:               precision    recall  f1-score   support
#
#         -1.0       0.93      0.91      0.92      1470
#          1.0       0.93      0.94      0.93      1847
#
#     accuracy                           0.93      3317
#    macro avg       0.93      0.92      0.92      3317
# weighted avg       0.93      0.93      0.93      3317

# %%
train_sizes_model, train_scores_model, valid_scores_model, *_ =learning_curve(model, x, y,cv=5,
                    scoring='accuracy',n_jobs=-1)
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.scatter(x=train_sizes_model,y= train_scores_model.mean(axis=1))
ax.scatter(x=train_sizes_model,y=valid_scores_model.mean(axis=1))
ax.plot(train_sizes_model,train_scores_model.mean(axis=1))
ax.plot(train_sizes_model,valid_scores_model.mean(axis=1))
ax.set_xlabel('Data Range')
ax.set_ylabel('Accuracy')
ax.set_title('Learning Curve')
plt.show()

# %% [markdown]
# ## Jacinta
# Use Decision trees with parameter: max_depth = 10

# %% [markdown]
# Use SVM with parameter: Kernel = rbf, C=1

# %% [markdown]
# Use Logistic Regression with parameter: solver = liblinear, C=1

# %% [markdown]
# Note: we did not implement KNNs since it will be computationally expensive on applying it in ensemble models
